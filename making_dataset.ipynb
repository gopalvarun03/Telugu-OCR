# %%
import numpy as np
import argparse
import time
import cv2 as cv
import matplotlib.pyplot as plt
import random
from PIL import Image, ImageDraw, ImageFont
import re
import os

# %%
names = ['Agni Suktam', 'agnisUktam', 'Advaita Shatakam', 'A no bhadrAH Suktam',
         'UdakashAnti Mantra', 'Rigveda Mandala 1', 'Rigveda Mandala 2', 'Rigveda Mandala 3',
         'Rigveda Mandala 4', 'Rigveda Mandala 5', 'Rigveda Mandala 6', 'Rigveda Mandala 7',
         'Rigveda Mandala 8', 'Rigveda Mandala 9', 'Rigveda Mandala 10', 'Selected verses from Rigveda',
         'oShadhIsUktam', 'Kumara Suktam', 'khilas 1', 'Ganapati sUkta from Rigveda',
         'Shri Ganapati Atharvashirsha Upanishat or Ganapati Upanishat with Accents',
         'Gosthasukta', 'Go Samuha Suktam', 'First mantra of each Veda', 'Chamakaprashna',
         'Taittiriya AraNyaka', 'Taittiriya Brahmanam', 'Taittiriya Samhita 1', 'Taittiriya Samhita',
         'TaittiriyAranyakam aruNaprashnaH', 'Trisuparna Suktam', 'durgAsUktam', 'devIsukta (Rigveda)',
         'dhanurveda', 'Dhruvasuktam Rigveda', 'Vedokta Sabija Navagraha Mantra Japa Prayogah', 'naShTa dravya prApti sUktam',
         'NakShatrasukta', 'Narayanasukta', 'nAsadIya sUkta (Rigveda )', 'PavamAnasukta', 'Pitrisuktam', 'Purushasukta',
         'Purushasukta from Shuklayajurveda', 'Krityaapariharanasuktam or Bagalamukhisuktam', 'brahmaNaspatisUktam sasvara',
         'Bhagya Suktam or Pratah Suktam', 'shrIbhUsUktam', 'bhUsUktam', 'Mantrapushpa', 'mantrapuShpAnjali', 'Manyu Suktam',
         'Maha Sauram', 'Medhasukta', 'rakShoghna sUkta Rigveda Mandala 4 and 10', 'rAtrisUktam', 'Rashtra Suktam',
         'rudram (praise of Lord Shiva) namakam and chamakam', 'Rudrapanchakam', 'Rudraprashna',
         'Shri Shuklayajurvediya Sasvara Rudrashtadhyayi', 'Shri Shuklayajurvediya Rudrashtadhyayi', 'Varuna Suktam 1',
         'Varuna Suktam 2', 'Vastu Suktam', 'vishvakarmasUktam', 'Shri Vishnu Suktam 2', 'Vishnusuktam', 'Vedamantramanjari 1',
         'Vedamantramanjari 2', 'Vedamantramanjari 3', 'Praise of Vedas from Shrimad Bhagavata Purana Skandha 10 Adhyaya 87',
         'Shantipatha', 'Shasta Suktam', 'Shivapujana Vaidika Shodashopachara', 'Shraddha Suktam', 'shrI sUkta (Rigveda)',
         'Samvada or Akhyana sukta from Rigveda Samhita Mandala 10', 'sanj~nAnasUkta', 'Rigvediya Sandhya Vandana',
         'Shukla YajurvedIya SandhyA Morning-Noon-Evening', 'Samaveda Samhita Kauthuma ShAkha', 'Suryasukta from Rigveda',
         'SaubhagyalakShmi Upanishad', 'Svasti Suktam', 'hiraNyagarbhasUktam']

# %%
# load the txt file and read the file line by line.
def read_file_lines(filename):
    lines = []
    try:
        with open(filename, 'r') as file:
            for line in file:
                lines.append(line.strip())  # Remove trailing newline characters
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

    return lines

# %%
dir = '/home/ocr/teluguOCR'
text_file_paths = []
for x in names:
  text_file_paths.append(dir + '/html_transcriptions/' + x + '.txt')#path to text file in "html_transcriptions" folder
font_paths =[dir + "/fonts/" + x for x in os.listdir("/home/ocr/teluguOCR/fonts/")]

print(text_file_paths)
# Out:
# ['/home/ocr/teluguOCR/html_transcriptions/Agni Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/agnisUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Advaita Shatakam.txt', '/home/ocr/teluguOCR/html_transcriptions/A no bhadrAH Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/UdakashAnti Mantra.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 1.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 2.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 3.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 4.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 5.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 6.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 7.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 8.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 9.txt', '/home/ocr/teluguOCR/html_transcriptions/Rigveda Mandala 10.txt', '/home/ocr/teluguOCR/html_transcriptions/Selected verses from Rigveda.txt', '/home/ocr/teluguOCR/html_transcriptions/oShadhIsUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Kumara Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/khilas 1.txt', '/home/ocr/teluguOCR/html_transcriptions/Ganapati sUkta from Rigveda.txt', '/home/ocr/teluguOCR/html_transcriptions/Shri Ganapati Atharvashirsha Upanishat or Ganapati Upanishat with Accents.txt', '/home/ocr/teluguOCR/html_transcriptions/Gosthasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/Go Samuha Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/First mantra of each Veda.txt', '/home/ocr/teluguOCR/html_transcriptions/Chamakaprashna.txt', '/home/ocr/teluguOCR/html_transcriptions/Taittiriya AraNyaka.txt', '/home/ocr/teluguOCR/html_transcriptions/Taittiriya Brahmanam.txt', '/home/ocr/teluguOCR/html_transcriptions/Taittiriya Samhita 1.txt', '/home/ocr/teluguOCR/html_transcriptions/Taittiriya Samhita.txt', '/home/ocr/teluguOCR/html_transcriptions/TaittiriyAranyakam aruNaprashnaH.txt', '/home/ocr/teluguOCR/html_transcriptions/Trisuparna Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/durgAsUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/devIsukta (Rigveda).txt', '/home/ocr/teluguOCR/html_transcriptions/dhanurveda.txt', '/home/ocr/teluguOCR/html_transcriptions/Dhruvasuktam Rigveda.txt', '/home/ocr/teluguOCR/html_transcriptions/Vedokta Sabija Navagraha Mantra Japa Prayogah.txt', '/home/ocr/teluguOCR/html_transcriptions/naShTa dravya prApti sUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/NakShatrasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/Narayanasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/nAsadIya sUkta (Rigveda ).txt', '/home/ocr/teluguOCR/html_transcriptions/PavamAnasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/Pitrisuktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Purushasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/Purushasukta from Shuklayajurveda.txt', '/home/ocr/teluguOCR/html_transcriptions/Krityaapariharanasuktam or Bagalamukhisuktam.txt', '/home/ocr/teluguOCR/html_transcriptions/brahmaNaspatisUktam sasvara.txt', '/home/ocr/teluguOCR/html_transcriptions/Bhagya Suktam or Pratah Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/shrIbhUsUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/bhUsUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Mantrapushpa.txt', '/home/ocr/teluguOCR/html_transcriptions/mantrapuShpAnjali.txt', '/home/ocr/teluguOCR/html_transcriptions/Manyu Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Maha Sauram.txt', '/home/ocr/teluguOCR/html_transcriptions/Medhasukta.txt', '/home/ocr/teluguOCR/html_transcriptions/rakShoghna sUkta Rigveda Mandala 4 and 10.txt', '/home/ocr/teluguOCR/html_transcriptions/rAtrisUktam.txt', '/home/ocr/teluguOCR/html_transcriptions/Rashtra Suktam.txt', '/home/ocr/teluguOCR/html_transcriptions/rudram (praise of Lord Shiva) namakam and chamakam.txt', '/home/ocr/teluguOCR/html_transcriptions/Rudrapanchakam.txt',  ...

# %%
f_out = open("/home/ocr/teluguOCR/Dataset/labels.txt", 'w')
for transcription in text_file_paths:
    lines = read_file_lines(transcription)
    for x in lines:
        f_out.write(x + "\n")
f_out.close()

# %%
def get_text_dimensions(text_string, font):
    if font.getmask(text_string).getbbox() == None:
      return [0,0]
    text_width = font.getmask(text_string).getbbox()[2]
    text_height = font.getmask(text_string).getbbox()[3]

    return [text_width, text_height]

def draw_telugu_text(text, font_path, font_size, text_color=(0, 0, 0)):
    font = ImageFont.truetype(font_path, font_size)

    # Get the size of the text
    text_size = get_text_dimensions(text, font)

    height = text_size[1] + 100 #image height plus 10(buffer for clear image)
    width = text_size[0] + 20 #Image width plus 10(buffer for clear image)
    img = Image.new("RGB", (width, height), "white")
    draw = ImageDraw.Draw(img)

    # Calculate the position to center the text
    x = (img.width - text_size[0]) // 2
    y = (img.height - text_size[1]) // 2

    draw.text((x, y), text, fill=text_color, font=font)
    
    # removing the excess white space on top and bottom
    image = np.array(img)
    non_zeros = []
    for i in range(image.shape[0]):
      if np.sum(image[i]) != 255*image.shape[1]*3:
        non_zeros.append(i)
    
    image = image[non_zeros[0]-5:non_zeros[-1]+5,:,:]
    img = Image.fromarray(image)
  
    return img

# %%
acchulu = ['అ', 'ఆ', 'ఇ', 'ఈ', 'ఉ', 'ఊ', 'ఋ', 'ౠ', 'ఌ', 'ౡ', 'ఎ', 'ఏ', 'ఐ', 'ఒ', 'ఓ', 'ఔ', 'అం', 'అః']
hallulu = ['క', 'ఖ', 'గ', 'ఘ', 'ఙ',
           'చ', 'ఛ', 'జ', 'ఝ', 'ఞ',
           'ట', 'ఠ', 'డ', 'ఢ', 'ణ',
           'త', 'థ', 'ద', 'ధ', 'న',
           'ప', 'ఫ', 'బ', 'భ', 'మ',
           'య', 'ర', 'ల', 'వ', 'శ', 'ష', 'స', 'హ', 'ళ', 'క్ష', 'ఱ']
vallulu = ['ా', 'ి', 'ీ', 'ు' , 'ూ', 'ృ', 'ౄ', 'ె', 'ే', 'ై', 'ొ', 'ో', 'ౌ', 'ం', 'ః', 'ఁ', 'ౕ', 'ౖ', 'ౢ' ]
connector = ['్']
numbers = ['౦', '౧', '౨', '౩', '౪', '౫', '౬', '౭', '౮', '౯']

varnmala = acchulu + hallulu + vallulu + connector + numbers + [' '] 

print(len(varnmala))
# Out:
# 85

# %%
def cleaning_the_text_2(string):
    # remove leading and trailing spaces
    string = string.strip()
    for x in string:
        if x in varnmala:
            continue
        else:
            string = string.replace(x, '')
    return string

# %%
s = 'ట' + 'వ' + 'ర' + connector[0]  + 'స' + 'ర'+ connector[0] + 'క'  + 'ి'  + 'ల'
print(s)

i = 1
for path in font_paths:
    img = draw_telugu_text(s, path, 64)
    cv.imwrite("/home/ocr/teluguOCR/test" + str(i) + ".png", np.array(img))
    i += 1
# Out:
# టవర్సర్కిల

# %%
lines = read_file_lines(dir + '/Dataset/labels.txt')
f_str = open(dir + '/Dataset/strings.txt', 'w')

number = 0
for s in lines:
    s = cleaning_the_text_2(s)
    s = re.sub("\s\s+" , " ", s)
    if(s=='' or s == None or s == ' '):
        continue
    number += 1
    f_str.write(s + '\n')
f_str.close()

print(number)
print(len(lines))

# %%
import cv2 as cv
import random

start = 0
lines = read_file_lines(dir + '/Dataset/strings.txt')
f_final = open("/home/ocr/teluguOCR/Dataset/final_strings.txt", 'w')

indx = 1
for s in lines:
  # random choice of fonts
  for font_path in random.sample(font_paths, 3):
    Img = draw_telugu_text(text = s, font_path = font_path, font_size = 64)
    m = Img.size[1]//40
    if m == 0 or Img.size[0]//m == 0:
      continue
    Img = Img.resize((Img.size[0]//m, 40))
    cv.imwrite(dir + '/Dataset/Images/Image' + str(indx) + '.png', np.array(Img))
    f_final.write(s + '\n')
    del Img
    del m
    indx+=1
  print(indx, end = '\r')

# %%
import os

print(len(os.listdir("/home/ocr/teluguOCR/Dataset/Cropped_Dataset/Images/")))
print(len(os.listdir("/home/ocr/teluguOCR/Dataset/Cropped_Dataset/Labels/")))

# %%
import cv2 as cv
import torch
import matplotlib.pyplot as plt
import random

num = random.randint(1, 189531 + 1)
img1 = cv.imread('/home/ocr/teluguOCR/Dataset/Images/Image' + str(num) + '.png')

img2 = torch.load('/home/ocr/teluguOCR/Dataset/Noised_Images/Image' + str(num) + '.pt')

print(torch.max(img2), " | ", torch.min(img2))
print(img2.shape)

f_str = open('/home/ocr/teluguOCR/Dataset/final_strings.txt', 'r')
lines = f_str.readlines()

print(lines[num-1])

plt.figure(figsize=(30, 30))
plt.subplot(1, 2, 1)
plt.imshow(img1, cmap = 'gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(img2, cmap = 'gray')
plt.title('Noised Image')

plt.show()
